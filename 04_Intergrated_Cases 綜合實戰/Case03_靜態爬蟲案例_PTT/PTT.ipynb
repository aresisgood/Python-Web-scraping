# %% [markdown]
# # 建置爬蟲核心工具箱 (Environment Setup)
#
# 本單元引入爬蟲三大支柱：**Requests** (模擬請求)、**BeautifulSoup** (解析 HTML) 、 **JSON** (資料交換)與**re** (正則表達式)。<br>
# 我們將使用 `requests` 與 PTT 伺服器通訊，並指定高效的 `lxml` 引擎協助 `BeautifulSoup` 提取標題與內文。<br>
# 請跟著老師填寫下方程式碼，完成自動化爬蟲的環境初始化。

# %%
# 若尚未安裝需要的套件，可在終端或 notebook 執行：
# !pip install requests beautifulsoup4 lxml

import requests         # 發送 HTTP 請求，用來從網站抓取網頁內容
from bs4 import BeautifulSoup as bs  # 解析 HTML / XML，將字串轉成可以操作的樹狀結構
import lxml             # 上課用的解析器（解析器需已安裝）
import time             # 取得目前時間，或讓程式暫停一段時間，做延遲，避免被 PTT 封鎖
import json             # 處理 JSON 格式的資料（例如 API 回傳或儲存設定）
import re               # 正規表達式

# %% [markdown]
# 在開始爬蟲之前，我們需要先模擬瀏覽器的行為。首先，我們將 PTT 股票版的搜尋網址（包含關鍵字「0050」）準備好，接著使用 requests.get() 向伺服器敲門並索取資料。確認伺服器回應成功（狀態碼 200）後，我們再利用 BeautifulSoup 這個強大的工具，將雜亂的 HTML 原始碼解析成容易提取的物件。

# %%
# 構造 GET 請求網址：`?` 宣告參數開始，`&` 用來連接多個條件
url = 'https://www.ptt.cc/bbs/Stock/search?page=2&q=0050'

# 發送 GET 請求到該網址
# 提示：requests 會回傳一個 Response 物件。
response = requests.get(url)

# 簡單檢查是否成功收到回應（HTTP 200 表示成功）
if response.status_code != 200:
    raise RuntimeError(f"取得資料失敗，狀態碼: {response.status_code}")

# 使用 BeautifulSoup 解析回傳的 HTML（使用 lxml 解析器，需要先安裝 lxml）
# res.text 就是你在瀏覽器按右鍵「檢視網頁原始碼」看到的那些 HTML 內容
soup = bs(response.text, 'lxml')

# %% [markdown]
# 接下來是爬蟲最關鍵的一步：資料定位。請大家在瀏覽器按 F12 觀察，會發現 PTT 列表中的每一篇文章，其實都是一個 class 為 r-ent 的 div 區塊。我們使用 BeautifulSoup 的 .select() 方法，像篩子一樣把所有符合 div.r-ent 特徵的區塊都撈出來，存成一個列表 (List)。

# %%
# 使用 CSS 選擇器選取所有文章區塊
# PTT 文章列表中每篇文章的外層容器，元素組成: <div class="r-ent"> ... </div>
post_entries = soup.select('div.r-ent')

# 檢查點 : 印出數量看有沒有抓到東西
# print(len(post_entries))
for p in post_entries:
    print(p)
# Out:
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">13</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1774797181.A.FD0.html">[請益] 0050/00692更換00631L</a>
# </div>
# <div class="meta">
# <div class="author">ian7202133</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E8%AB%8B%E7%9B%8A%5D+0050%2F00692%E6%9B%B4%E6%8F%9B00631L">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Aian7202133">搜尋看板內 ian7202133 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/29</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1774601902.A.659.html">Re: [心得] 打敗大盤0050的勝率與期望值</a>
# </div>
# <div class="meta">
# <div class="author">clgai</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E5%BF%83%E5%BE%97%5D+%E6%89%93%E6%95%97%E5%A4%A7%E7%9B%A40050%E7%9A%84%E5%8B%9D%E7%8E%87%E8%88%87%E6%9C%9F%E6%9C%9B%E5%80%BC">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Aclgai">搜尋看板內 clgai 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/27</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">54</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1774597984.A.0E2.html">[心得] 打敗大盤0050的勝率與期望值</a>
# </div>
# <div class="meta">
# <div class="author">haug</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E5%BF%83%E5%BE%97%5D+%E6%89%93%E6%95%97%E5%A4%A7%E7%9B%A40050%E7%9A%84%E5%8B%9D%E7%8E%87%E8%88%87%E6%9C%9F%E6%9C%9B%E5%80%BC">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Ahaug">搜尋看板內 haug 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/27</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1774494528.A.DF2.html">[標的] 0050正二分割為什麼需要停止交易</a>
# </div>
# <div class="meta">
# <div class="author">Shrugg</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%A8%99%E7%9A%84%5D+0050%E6%AD%A3%E4%BA%8C%E5%88%86%E5%89%B2%E7%82%BA%E4%BB%80%E9%BA%BC%E9%9C%80%E8%A6%81%E5%81%9C%E6%AD%A2%E4%BA%A4%E6%98%93">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3AShrugg">搜尋看板內 Shrugg 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/26</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">49</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1774333126.A.BEE.html">[新聞] ETF股王「0050正2」分割前最後買進日　下</a>
# </div>
# <div class="meta">
# <div class="author">rz2x</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+ETF%E8%82%A1%E7%8E%8B%E3%80%8C0050%E6%AD%A32%E3%80%8D%E5%88%86%E5%89%B2%E5%89%8D%E6%9C%80%E5%BE%8C%E8%B2%B7%E9%80%B2%E6%97%A5%E3%80%80%E4%B8%8B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Arz2x">搜尋看板內 rz2x 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/24</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">6</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1774260440.A.1E1.html">[新聞] 外資賣超839億元、賣超0050逾8.7萬張最多</a>
# </div>
# <div class="meta">
# <div class="author">relax911</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%A4%96%E8%B3%87%E8%B3%A3%E8%B6%85839%E5%84%84%E5%85%83%E3%80%81%E8%B3%A3%E8%B6%850050%E9%80%BE8.7%E8%90%AC%E5%BC%B5%E6%9C%80%E5%A4%9A">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Arelax911">搜尋看板內 relax911 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/23</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">69</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1773578051.A.3F0.html">[標的] 00713 vs 0050</a>
# </div>
# <div class="meta">
# <div class="author">tyce8ton</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%A8%99%E7%9A%84%5D+00713+vs+0050">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Atyce8ton">搜尋看板內 tyce8ton 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/15</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">52</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1773412545.A.534.html">[請益] 0050正二分割期間(3/24-31)避險</a>
# </div>
# <div class="meta">
# <div class="author">ben2227486</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E8%AB%8B%E7%9B%8A%5D+0050%E6%AD%A3%E4%BA%8C%E5%88%86%E5%89%B2%E6%9C%9F%E9%96%93%283%2F24-31%29%E9%81%BF%E9%9A%AA">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Aben2227486">搜尋看板內 ben2227486 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/13</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">21</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1773204595.A.AA2.html">Re: [標的] 0050持續買進</a>
# </div>
# <div class="meta">
# <div class="author">onekoni</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%A8%99%E7%9A%84%5D+0050%E6%8C%81%E7%BA%8C%E8%B2%B7%E9%80%B2">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Aonekoni">搜尋看板內 onekoni 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/11</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">91</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1773197787.A.277.html">Re: [標的] 0050持續買進</a>
# </div>
# <div class="meta">
# <div class="author">dasdstormer</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%A8%99%E7%9A%84%5D+0050%E6%8C%81%E7%BA%8C%E8%B2%B7%E9%80%B2">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Adasdstormer">搜尋看板內 dasdstormer 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/11</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">31</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1773030895.A.D8B.html">Re: [標的] 0050持續買進</a>
# </div>
# <div class="meta">
# <div class="author">DualKing</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%A8%99%E7%9A%84%5D+0050%E6%8C%81%E7%BA%8C%E8%B2%B7%E9%80%B2">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3ADualKing">搜尋看板內 DualKing 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">20</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1773027755.A.073.html">Re: [標的] 0050持續買進</a>
# </div>
# <div class="meta">
# <div class="author">onekoni</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%A8%99%E7%9A%84%5D+0050%E6%8C%81%E7%BA%8C%E8%B2%B7%E9%80%B2">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Aonekoni">搜尋看板內 onekoni 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1773023394.A.047.html">[標的] 0050持續買進</a>
# </div>
# <div class="meta">
# <div class="author">dasdstormer</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%A8%99%E7%9A%84%5D+0050%E6%8C%81%E7%BA%8C%E8%B2%B7%E9%80%B2">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Adasdstormer">搜尋看板內 dasdstormer 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/09</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">98</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1772940216.A.B05.html">[請益] 0050跟0056有在停利的嗎？</a>
# </div>
# <div class="meta">
# <div class="author">apple0123</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E8%AB%8B%E7%9B%8A%5D+0050%E8%B7%9F0056%E6%9C%89%E5%9C%A8%E5%81%9C%E5%88%A9%E7%9A%84%E5%97%8E%EF%BC%9F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Aapple0123">搜尋看板內 apple0123 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/08</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">8</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1772810466.A.60E.html">Re: [請益] 0050轉正二</a>
# </div>
# <div class="meta">
# <div class="author">ice80712</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E8%AB%8B%E7%9B%8A%5D+0050%E8%BD%89%E6%AD%A3%E4%BA%8C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Aice80712">搜尋看板內 ice80712 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">51</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1772790042.A.7A1.html">[新聞] 快訊／規模1.3兆0050換股！增刪5檔　華</a>
# </div>
# <div class="meta">
# <div class="author">takeshi911</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%BF%AB%E8%A8%8A%EF%BC%8F%E8%A6%8F%E6%A8%A11.3%E5%85%860050%E6%8F%9B%E8%82%A1%EF%BC%81%E5%A2%9E%E5%88%AA5%E6%AA%94%E3%80%80%E8%8F%AF">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Atakeshi911">搜尋看板內 takeshi911 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">42</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1772788894.A.2FE.html">Re: [新聞] 台股大跌0050打折！清流君曬0050歷史回</a>
# </div>
# <div class="meta">
# <div class="author">midas82539</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%8F%B0%E8%82%A1%E5%A4%A7%E8%B7%8C0050%E6%89%93%E6%8A%98%EF%BC%81%E6%B8%85%E6%B5%81%E5%90%9B%E6%9B%AC0050%E6%AD%B7%E5%8F%B2%E5%9B%9E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Amidas82539">搜尋看板內 midas82539 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">32</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1772788377.A.780.html">[情報] 0050 006208 0056 成分股定期審核結果</a>
# </div>
# <div class="meta">
# <div class="author">q8977452</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+0050+006208+0056+%E6%88%90%E5%88%86%E8%82%A1%E5%AE%9A%E6%9C%9F%E5%AF%A9%E6%A0%B8%E7%B5%90%E6%9E%9C">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Aq8977452">搜尋看板內 q8977452 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">38</span></div>
# <div class="title">
# <a href="/bbs/Stock/M.1772752924.A.B6E.html">Re: [新聞] 台股大跌0050打折！清流君曬0050歷史回</a>
# </div>
# <div class="meta">
# <div class="author">newukyo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%8F%B0%E8%82%A1%E5%A4%A7%E8%B7%8C0050%E6%89%93%E6%8A%98%EF%BC%81%E6%B8%85%E6%B5%81%E5%90%9B%E6%9B%AC0050%E6%AD%B7%E5%8F%B2%E5%9B%9E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Anewukyo">搜尋看板內 newukyo 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/06</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/Stock/M.1772728835.A.134.html">Re: [新聞] 台股大跌0050打折！清流君曬0050歷史回</a>
# </div>
# <div class="meta">
# <div class="author">ice80712</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%8F%B0%E8%82%A1%E5%A4%A7%E8%B7%8C0050%E6%89%93%E6%8A%98%EF%BC%81%E6%B8%85%E6%B5%81%E5%90%9B%E6%9B%AC0050%E6%AD%B7%E5%8F%B2%E5%9B%9E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/Stock/search?q=author%3Aice80712">搜尋看板內 ice80712 的文章</a></div>
# </div>
# </div>
# <div class="date"> 3/06</div>
# <div class="mark"></div>
# </div>
# </div>

# %% [markdown]
# > **教學註記**：為優化課堂節奏，此函式已預先封裝供直接調用。
# > **核心機制**：
# > 1. **實例化**：執行 `datetime.now()` 捕捉系統當下時間點。
# > 2. **屬性存取**：透過 `.month` 動態提取月份整數，實現自動化更新。
# > 3. **month屬性**：呼叫month_extract()函式，得系統偵測的月份(整數，Ex:1 | 12)

# %%
from datetime import datetime

'''
練習如何從datetime物件動態提取月份，並傳遞給month使用
'''
def month_extract():
    # 1. 獲取當前時間物件 (Instantiation)
    # 這是動態的源頭，每次執行時都會抓取系統當下時間
    current_time: datetime = datetime.now()

    # 2. 提取屬性 (Attribute Extraction)
    # 找month屬性 => .month
    # 注意 : 屬性存取，不需要括號 ()
    This_month : int = current_time.month

    # 3.  驗證輸出
    # print(f"系統偵測時間:{current_time}")
    # print(f"提取月份:{This_month}")
    return This_month
if __name__ == "__main__":
    month_extract()

# %% [markdown]
# ### 任務：實作「上月文章過濾器」
#
# 我們已經抓到了所有文章區塊 (`post_entries`)，現在需要一個過濾器，只留下**上個月份**的資料。
#
# **實作要求：**
# 1.  **邏輯健壯性**：程式必須能正確處理 **1月份執行時** 的狀況（需自動回推至去年 12月），不能報錯或抓不到資料。
# 2.  **精準匹配**：請使用 `startswith` 搭配 `/` 符號，確保不會將 1 月誤判為 11 月。
# 3.  **輸出結果**：遍歷列表，印出所有符合條件的日期字串（需去除多餘空白）。
#
# *請開始 Coding！*

# %%
# month_extract() 已經取得當前月份
# 為甚麼需要寫這個if判斷? 請學員討論
if int(month_extract()) == 1:
    last_month = 12
else:
    last_month = month_extract() -1

#Pattern(匹配的格式)，我們預期要匹配到"1/"、"2/"、...、"12/"
# f-string（格式化字串）：在字串前加 f，使用 {變數} 直接嵌入變數值，簡潔替代 str.format()
pattern = f"{last_month}/"

#.strip():去除前後空白
for post in post_entries:
    date_tag = post.find("div", class_ = "date")
    date_text = date_tag.text
    
    if date_text.strip().startswith(pattern):
        print(date_text.strip())
# Out:
# 3/29
# 3/27
# 3/27
# 3/26
# 3/24
# 3/23
# 3/15
# 3/13
# 3/11
# 3/11
# 3/09
# 3/09
# 3/09
# 3/08
# 3/06
# 3/06
# 3/06
# 3/06
# 3/06
# 3/06

# %% [markdown]
# ### 任務：打造網址收集器 (URL Collector)
#
# 我們已經成功篩選出上個月的文章了，現在下一步是**把這些文章的連結存起來**，這樣我們等一下才能進去每一篇文章爬內文。
#
# **請依照以下邏輯完成程式碼：**
#
# #### 1. 準備工作
# *   建立一個空的列表 (List)，取名為 `target_urls`，用來存放最終結果。
# *   建立一個變數 `base_url`，內容為 `"https://www.ptt.cc"`。
#     *   *思考：為什麼需要這個變數？直接用爬下來的連結不行嗎？*
#
# #### 2. 擷取連結 (在迴圈內執行)
# 當日期符合條件時，我們要進行以下動作：
# *   **定位標籤**：找到文章區塊內的 `<a>` 標籤（代表超連結）。
# *   **取得屬性**：使用 `post.a['href']` 語法，抓取該標籤的 `href` 屬性。這通常會是一個**相對路徑** (例如 `/bbs/Stock/...`)。
#
# #### 3. 補全與儲存
# *   **拼接網址**：將 `base_url` 與剛剛抓到的相對路徑相加，變成可以點擊的完整網址。
# *   **加入列表**：使用 `.append()` 方法，將完整網址存入 `target_urls`。
#
# #### 4. 驗收
# *   迴圈結束後，印出 `target_urls`，確認裡面是不是都是完整的 `https://...` 網址。

# %%
# 欲取得上個月的每一篇討論文章，我們首先要取得的就是其個別的網址
# 1. 初始化容器：準備一個空列表來裝我們抓到的網址
target_urls = []

# PTT主網域變數
# 2. 定義主網域：PTT 的連結通常是「相對路徑」，需要補上開頭
base_url = "https://www.ptt.cc"

'''
<a href="/bbs/Stock/M.1764646716.A.193.html">[新聞] 台達電營運 大摩按讚</a>
這是我們的目標元素
'''
# post.a 代表找到該區塊內的第一個<a>超連結標籤
# ['href']是像查字典一樣，取出該標籤的href屬性值
# 字串拼接：主網域 + 相對路徑 = 完整網址
# 將結果加入列表
for p in post_entries:
    date_tag = p.find("div", class_ = "date")
    date_text = date_tag.text
    
    if date_text.strip().startswith(pattern):
        p_url = p.select_one("div.title > a[href]")["href"]
        complete_url = base_url + p_url
        target_urls.append(complete_url)
        
print(len(target_urls))
# Out:
# 20

# %% [markdown]
# ### 任務：儲存多篇文章資料
#
# 我們現在要進入每一篇文章抓取詳細資料。請大家想像：
# *   **每一篇文章** 就像一張「個人資料卡」(Dictionary)。
# *   我們需要一本「通訊錄」(List) 來把這些卡片全部裝起來。
#
# **請依照以下結構撰寫程式：**
#
# 1.  **建立總容器**：
#     *   在迴圈外面，建立一個空列表 `articles_data = []`。
#
# 2.  **單篇文章處理 (在迴圈內)**：
#     *   發送請求 (`requests`) 並解析 (`BeautifulSoup`)。
#     *   抓取標題 (`title`)。
#     *   **關鍵步驟**：建立一個字典 `article_info`，把標題和網址存進去。
#         *   範例：`article_info = {"title": title, "url": target_url}`
#
# 3.  **歸檔**：
#     *   使用 `.append()` 把這篇文章的字典，放入總容器 `articles_data` 中。

# %%
from time import sleep
import pprint

# 建立大列表
articles_data = []

# 建立「單篇文章」的字典(Dict)
# 把「單篇文章」的字典裝進大列表裡面
for target_url in target_urls:
    try:
        res = requests.get(target_url)
        soup = bs(res.text, 'lxml')
        # <span class="article-meta-value" xpath="1">[請益] 0050/00692更換00631L</span>
        # 取標題
        meta_value = soup.select("span.article-meta-value")

        if len(meta_value) >= 3:
            title = meta_value[2].text
        else:
            title = "格式錯誤"

        # 取時間
        if len(meta_value) >= 4:
            time = meta_value[3].text
        else:
            time = "格式錯誤"

        # 取留言
        # <span class="f3 push-content" xpath="1">: 沒有不行</span>
        comments = []
        comment_list = soup.select("span.f3 push-content")

        for c in comment_list:
            comments.append(c.text)
            
        # 取內容?

        # PTT (批踢踢實業坊)，它的HTML結構並非現代化的語意標籤 (Semantic HTML)，而是由舊式BBS系統轉換而來
        # 這導致「內文」並不是包在一個乾淨的 <p> 或 <article-body> 標籤中
        # 而是作為「文字節點 (Text Node)」散落在 #main-content元素內，與標題、時間、推文混雜在一起
        # 這裡我們不需要保留「標題列」或「時間」，我們使用beautifulsoup的decomposed()方法將不需要的元素去除
        
        # 步驟一 : 鎖定主內容元素
        main_content = soup.select_one("#main-content")

        # 確保程式不會在找不到網頁內容時不會崩潰 (Crash)
        # 使用 if xxx: 若遇到xxx=None 不會停止執行而是「優雅地跳過」
        if main_content:

            # 步驟二: 移除不要的元素
            # 批次處理：利用 CSS Selector 的逗號 , 功能，一次選取所有不要的類別（Meta + Push），一個迴圈解決，不需要寫好幾個迴圈。
            # 不要的元素(1) : .article-metaline (標題、作者、時間)
            # 不要的元素(2) : .article-metaline-right (看板名稱)
            # 不要的元素(3) : span (零散資訊)
            # 不要的元素(4) : div.push (推文區塊)
            unwanted_elements = main_content.select(".article-metaline, .article-metaline-right, span, div.push")

            #步驟三: 執行銷毀
            for element in unwanted_elements:
                element.decompose()
                
        # 複習 .strip(), replace() 清理 main_content 內容
        content = main_content.text.strip().replace("\n", " ")

        article_info = {
            "title" : title,
            "url" : target_url,
            "time" : time,
            "comments" : comments,
            "content" : content,
        }

        articles_data.append(article_info)
        print(f"已成功爬取: {title}")

        sleep(1)

    except Exception as e:
        print(f"爬取失敗: {target_url}，錯誤原因: {e}")

pprint.pprint(articles_data)
# Out:
# 已成功爬取: [請益] 0050/00692更換00631L
# 已成功爬取: Re: [心得] 打敗大盤0050的勝率與期望值
# 已成功爬取: [心得] 打敗大盤0050的勝率與期望值
# 已成功爬取: [標的] 0050正二分割為什麼需要停止交易
# 已成功爬取: [新聞] ETF股王「0050正2」分割前最後買進日　下
# 已成功爬取: [新聞] 外資賣超839億元、賣超0050逾8.7萬張最多
# 已成功爬取: [標的] 00713 vs 0050
# 已成功爬取: [請益] 0050正二分割期間(3/24-31)避險
# 已成功爬取: Re: [標的] 0050持續買進
# 已成功爬取: Re: [標的] 0050持續買進
# 已成功爬取: Re: [標的] 0050持續買進
# 已成功爬取: Re: [標的] 0050持續買進
# 已成功爬取: [標的] 0050持續買進
# 已成功爬取: [請益] 0050跟0056有在停利的嗎？
# 已成功爬取: Re: [請益] 0050轉正二
# 已成功爬取: [新聞] 快訊／規模1.3兆0050換股！增刪5檔　華
# 已成功爬取: Re: [新聞] 台股大跌0050打折！清流君曬0050歷史回
# 已成功爬取: [情報] 0050 006208 0056 成分股定期審核結果
# 已成功爬取: Re: [新聞] 台股大跌0050打折！清流君曬0050歷史回
# 已成功爬取: Re: [新聞] 台股大跌0050打折！清流君曬0050歷史回
# [{'comments': [],
#   'content': '各位股票大神，想請問目前持有標的大多為市值型ETF長期投資，搭配一些信貸，以前有質壓目前沒有，想把台股部位精簡成只有00631L，美股持有00662，不知道大家覺得這樣配置有什麼問題嗎？  '
#              '原本標的： 0050 3張 00631L 6張 00646 13張 00662 14張 00692 32張 轉換成 00631L '
#              '00662 ----- Sent from JPTT on my Samsung SM-S9210.  -- '
#              '逆價差我再查詢看看感謝你的回覆，正二是之前慢慢換越換越多..',
#   'time': 'Sun Mar 29 23:12:57 2026',
#   'title': '[請益] 0050/00692更換00631L',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1774797181.A.FD0.html'},
#  {'comments': [],
#   'content': '台積電在2000年時來到高點約220左右 不含配息，大概等了快20年，才又回到這個價格 尤其是2000-2009年，是死魚一條 '
#              '所以很多人不喜歡回測，因為回測總是挑數字好看的那一段 現在說台積電好棒棒，沒錯啊，但如果2000年買 '
#              '然後套了這麼久，你還會這樣說嗎？ https://files.catbox.moe/ck00pc.png ----- Sent '
#              'from  on my iPhone  --',
#   'time': 'Fri Mar 27 16:58:19 2026',
#   'title': 'Re: [心得] 打敗大盤0050的勝率與期望值',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1774601902.A.659.html'},
#  {'comments': [],
#   'content': '近幾年因為台積電相關產業,0050的績效表現都很好,所以統計了一下長期(2004.1.1~2026.2 '
#              '.23的還原除權息數據)的數據,能超越0050的勝率是多少?超越0050的期望值和失敗的期望值 是多少? '
#              'https://i.imgur.com/6yGWfio.jpeg 22年投資0050績效是賺15倍, 100萬變1600萬. '
#              '結果22年全上市股票能贏0050的只有12.5%,回推10年/5年勝率16.5%/13%.,不管長短期勝率 都在15%左右. '
#              'https://i.imgur.com/5Yj4RAj.jpeg '
#              '22年的長期期望值-725%,回推10年/5年期望值-16.9%/-9.15% 投資時間愈長期望值愈低.  結論: '
#              '1.對投資沒特別有興趣,沒時間研究,直接買大盤0050就對了. '
#              '2.有投資個股要好好統計長期績效,長期年化報酬率(用xirr計算),每年報酬率跟大盤0050比 '
#              '較,看看是否超越自己定的超額報酬,去調整選股策略和標的的目標報酬率. 不然就浪費了長期投資下來的資產複利和機會成本   --',
#   'time': 'Fri Mar 27 15:53:02 2026',
#   'title': '[心得] 打敗大盤0050的勝率與期望值',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1774597984.A.0E2.html'},
#  {'comments': [],
#   'content': '滿滿疑問，剛剛被刪文。 只是想跟各位股市老手專家請益  0050正2分割需要停止交易的原因是什麼 '
#              '為什麼一樣的股票除權除息也是有分割的程序 它卻不用停止交易  有沒誰可以給一個比較有說服力的原因的    進退場機制：    '
#              '----- Sent from JPTT on my Samsung SM-S9180.  --',
#   'time': 'Thu Mar 26 11:08:46 2026',
#   'title': '[標的] 0050正二分割為什麼需要停止交易',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1774494528.A.DF2.html'},
#  {'comments': [],
#   'content': '原文標題： ETF股王「0050正2」分割前最後買進日\u3000下周2萬可入手  原文連結： '
#              'https://finance.ettoday.net/news/3137433  發布時間： 2026-03-24 '
#              '10:05  記者署名： 記者巫彩蓮  原文內容： '
#              '今（24）日為「ETF股王」元大台灣50正2（00631L）分割前最後交易日，以目前價格，估 計分割比例為1拆22， '
#              '，到9點半左右股價為450元，漲幅約1.63%，；屆時，將成為市場上最便宜的台股正2 ETF。  '
#              '00631L追蹤「臺灣50指數」單日正向兩倍報酬，由於具備複利效果，多頭行情波段明確時，00631L的累積報酬會超過同期間 '
#              '0050的兩倍報酬。統計00631L成立以來截至昨（23）日報酬達2102%，大幅超越0050的560 '
#              '%，績效特性逐漸得到市場關注。  據集保結算所截至上周五（20日）當周資料顯示，00631L總投資人數8.3萬人，其中零股 '
#              '投資人數多達5.7萬人，以目前1拆22架構下，持有46股以上零股投資人即可轉為1張以上 '
#              '，未來可進行整張交易，或用分割後較低價格補足剩餘零股至整張，增加交易彈性。  '
#              '至於對比直接操作台指期，除了00631L會由投信管控槓桿倍數目標為2倍，損益波動相對 '
#              '可控，若面對下跌市況，00631L投資人不用額外補保證金，最大虧損最多為投入本金（買 '
#              '入股款），簡單來說，00631L為槓桿倍數穩定，且期貨交易風險由投信管理與承擔的投資 工具，具有極大的交易便利性與優勢。  '
#              '近期台股走勢震盪，00631L也成為不少投資人加碼標的，統計3月以來至19日，00631L累 '
#              '積淨申購金額達153億元，其中3月4日、3月9日台股大跌兩日合計逾76億，最新規模與投 '
#              '資人數分別來到729億、8.3萬人新高。  00631L於明日至下周一暫停交易，下周二將以新價格恢復交易，會以今日基金淨值進行分 '
#              '割，惟至下周二恢復交易前仍會波動，故可參考元大投信官網公布之00631L下周一基金淨 值，及下周二盤中即時估計淨值。  '
#              '法人分析，在AI、高效能運算及半導體產業持續帶動下，權值股仍具長線成長動能，在台 '
#              '股多頭格局未明顯改變的情況下，台股正2系列商品成為市場資金放大報酬的重要工具。 '
#              '如今00631L分割後將成為市場中最便宜、低門檻的正2標的，依過往元大台灣50（0050） '
#              '、富邦科技（0052）經驗，預計將再掀起一波全新交易熱潮。  心得/評論： 正2賭徒下好離手 下周二31日不是暴漲就是暴跌 '
#              '誰愛賭就是賭狗  沒錯 就是我 賭啦 不賭玩甚麼正2 買正2沒在跟你怕的啦  下週二準備暴賺 '
#              'ALLINNNNNNNNNNNNNNNNNN!!!!!!!!!!!!!  -- 這兩天都在開會啊 我也不想開會',
#   'time': 'Tue Mar 24 14:18:44 2026',
#   'title': '[新聞] ETF股王「0050正2」分割前最後買進日\u3000下',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1774333126.A.BEE.html'},
#  {'comments': [],
#   'content': '原文標題：  外資賣超839億元、賣超0050逾8.7萬張最多 這檔金融股竟高居第二名  原文連結：  '
#              'https://reurl.cc/Z2rddl  發布時間：  2026/03/23 17:30:50  記者署名：  楊伶雯  '
#              '原文內容：  台股23日收32,722.5點，大跌821.38點，失守33,000點，三大法人中僅投信買超，外資則  '
#              '是賣超839.23億元，統計外資賣超元大台灣50（0050）達87,814張最多，其次是賣超台新  '
#              '新光金（2887）72,426張，鴻海（2317）、台積電（2330）、金融股等都是外資提款標的  '
#              '，證券分析師坦言，戰事的不確定因素衝擊下，建議嚴控持股。  '
#              '台股早盤以33,334點開出，下跌209.88點，指數開低走低，一度下滑至32,461.09點，重  '
#              '挫1,082.79點，為盤中第八大跌點；權王台積電早盤失守1,800元，以1,790元開低，一度  '
#              '下滑至1,785元，終場收1,810元，下跌30元，影響大盤指數約237點。  '
#              '權值股重挫，台達電（2308）收1,410元，下跌65元；聯發科（2454）收1,625元，下跌75  '
#              '元；鴻海收196元，下跌7元；欣興（3037）、日月光投控（3711）、南亞科（2408）、緯  '
#              '穎（6669）、京元電（2449）等也都下跌。  '
#              '股后穎崴（6515）一度衝達8,450元，突破8,000元寫歷史新高，可惜終場收黑，以7,885  '
#              '元收盤，下跌45元；盤面上各類股僅造紙類股逆勢收紅，其餘各類股則是慘綠作收，大盤  '
#              '指數收在32,722.5點，下跌821.38點，為歷史第十一大跌點。  '
#              '三大法人賣超1,046.27億元，外資及陸資（不含外資自營商）賣超839.23億元，投信買超  '
#              '104.07億元，自營商賣超（合計）311.12億元，其中自營商（自行買賣）賣超60.25億元  '
#              '，自營商（避險）賣超250.87億元。  統計外資賣超前十名個股，賣超元大台灣最多，賣超87,814張，其次是賣超台新新光金  '
#              '72,426張，鴻海跌破200元，外資賣超28,425張，中鋼（2002）、台塑（1301）、力積電  '
#              '（6770）也是外資賣超標的，另外，金融股也遭外資提款，永豐金（2890）、合庫金（  '
#              '5880）、臺企銀（2834）、富邦金（2881）、玉山金（2884）、彰銀（2801）等都遭外資  '
#              '賣超逾萬張；外資買超第一名則是長榮航（2618），買超20,002張，其次是買超華邦電（  2344）13,049張。  '
#              '資深證券分析師簡伯儀表示，中東戰事的不確，恐慌指數升高，市場擔心油價上漲及通膨  '
#              '疑慮，後市仍要看戰事的發展，在市場偏觀望之下，要留意信用風險，嚴控持股，目前持  股不拉高，弱勢股則要減碼。  心得/評論：  '
#              '投資理財有賺有賠 詳情請看公開說明書。外資狂拋 0050 與台積電，大盤重挫失守；建  議緊盯配息動向，嚴控持股待止跌。  --',
#   'time': 'Mon Mar 23 18:07:18 2026',
#   'title': '[新聞] 外資賣超839億元、賣超0050逾8.7萬張最多',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1774260440.A.1E1.html'},
#  {'comments': [],
#   'content': '最近去銀行借信貸想要趁大盤回檔時買入，結果等手續用完看起來也沒有在往下了，但是 '
#              '利率還可以所以還是借了，想說要投入哪一個標的比較安穩呢？ '
#              '目前金額是185萬扣了代辦費9000分84期還款。最少要18期一個月目前要2.4-2.5萬 3.14%  '
#              '第一個方案是購買00713 我研究了一下713通常有5%的殖利率，一年可以有9萬股息，這樣一年還需要21萬的現今流 。  '
#              '方法二是0050 一年約2%可以3.5萬一年需要26.5萬的現金流。  目前手上整天槓桿率約112%  '
#              '我目前持有的庫存是144張0050 跟1090股vt 我自己是覺得依照目前的庫存假設vt扣完股息稅後為1% '
#              '一年約26萬如果用00713可能不需要擔心還款可以放著不動。 如果採用0050可能會需要一個月補幾千元  '
#              '再來是想說00713跟0050相關係數在高股息當中比較小可能可以起到分散的效果。 想聽聽大家的意見，謝謝。 '
#              '安全預備目前流動資金還有10萬，預計買股票以張為單位還會剩下一點，接著就是等股息 了。  '
#              'https://i.mopix.cc/vHOUxK.jpg  https://i.mopix.cc/jaid7P.jpg   '
#              '最後早上開盤追進去0050了 謝謝大家的建議  https://i.mopix.cc/pVPa2M.jpg    -- '
#              '講真的只用工資付的話大概要35%薪資 我願意借的因素是因為我現在的股息還能負擔多數費用 '
#              '對所以我覺得713優點是跟0050的低相關係數。 我槓桿率很低只有很少一部分 '
#              '指數附近的報酬就可以了，我覺得只要能撐完確實可能可以提早1-2年退休 '
#              '我沒有信貸投資的經驗啊，我也覺有時候多一個視角讓自己去思考沒有問題 '
#              '想說他績效過去還可以加上最大回撤相對小，然後分散一些我太集中的風險 '
#              '其實我覺得自己目前沒債券，資產的波動也算高買這個也算分散一點，不過我自己也有計 畫之後減持0050分去給vt '
#              '我利率是3%不過代辦費扣了要3.14,我當時有提供台股當作財產證明，好奇現在信貸要幾% 才是好 '
#              '想說用來代替債嗎？之前有一次看到有人說可以 我覺得槓桿率112其實不用很有種 '
#              '我之前26000問過後面發現還會往上頓悟了等待才是最大的風險 我也有想說還是一樣都買0050 '
#              '從殖利率跟報酬率上他有贏bndw,最大回撤上bndw約20% 713約25%我覺得取代一部分但是 短債類現金他無法取代 '
#              '我有想過不過要換劵商吧？不知道會不會很麻煩，台新的質押好爛 那我其實還是可以買50反正股息都還能擋差額其實還好也不是付不起 '
#              '有辦法直接換券商嗎？還是要賣光在買 感恩 好奇怎麼大家都那麼低才是正常的嗎？ 我自己是最高不能超過3%就覺得還能接受了 '
#              '我下次去找券商看看那一間比較低 我有想過2026年找時間在把一部分的0050拿去換vt，借來的因為怕匯率應該不會跑海外 '
#              '那我直接0050好了0056相關係數沒有低波動特性，我這樣直接買市值就好 我是去比較713跟50,56的最大回撤 '
#              '我比較0056回撤是比713大，713成立至今的irr其實比想像高，0056成立至今irr與713比 較713是贏56的 '
#              '比較年輕所以感覺先不用債，而且投資美股的債股息稅好高 其實我之前也有買0051,確實拖累報酬 '
#              '但是一開始買了1百多萬也是為了分散，後面想說vt更合適而且規模大0051規模太小了 但是713也有一定規模 不是只有2%多 '
#              '我之後會找看看便宜的券商看看能不能有更好的第一次不會殺價 '
#              '如果趨勢改了那713過去的績效就沒辦法參考了，畢竟我會考慮也是因為他以前的績效好 我覺得跟0050相關係數太高欸可能直接50了 '
#              '我預計下一次可能會找看看有沒有推薦的券商 我本來也是要買0050,只是這次有利息所以才找看看有沒有其他選擇 '
#              '我想說vt美股比例不少了，未來我會提高vt!的比例 '
#              '這個確實在台灣分散的成本太高了，我有想過找到合適的券商之後去買vxus,或是vea '
#              '美股估值好高，我覺得要買的話先買vt就好，感覺0050也是比較偏ai方面的 '
#              '我預計2026找機會最晚就是2027年初會轉移一部分錢到vt預期比例會到55:45了 沒有17是加上貸款的部分才有 '
#              '借來的不買vt是怕匯率，不過會慢慢提高vt比例的 快33了算中間 其實我不太敢預期那麼高 目前看來我會拿去買0050 '
#              '目前持股不再元大可以轉過去嗎？',
#   'time': 'Sun Mar 15 20:34:08 2026',
#   'title': '[標的] 00713 vs 0050',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1773578051.A.3F0.html'},
#  {'comments': [],
#   'content': '00631L 0050正二即將開始分割 3/24最終交易日 3/31恢復交易 中間有將近一禮拜時間無法交易 '
#              '萬一戰爭又有新的變數的話 等於資金被鎖一禮拜無法應變 總覺得是個超大的風險  所以股市菜雞來問一下各位大大打算怎麼做  '
#              '我只想得到先轉移幾成資金去其他正二 分割結束再轉回 不過這樣無可避免地要吃手續費+些微價差  還是有其他更好的方法?  --',
#   'time': 'Fri Mar 13 22:35:43 2026',
#   'title': '[請益] 0050正二分割期間(3/24-31)避險',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1773412545.A.534.html'},
#  {'comments': [],
#   'content': '某樓酸人說持續買是亂買，要看VIX跟油價進場才準確，昨天雙下滑就該進場了，會買在 低點。  可是3/3  油價 74.8  '
#              'https://i.mopix.cc/0ff74f.jpg  VIX 23  '
#              'https://i.mopix.cc/eus5fv.jpg  當時大盤 34323  而昨天  油價 80  VIX 23  '
#              '當時大盤 32771  如果按著油價與VIX來看，3/3的VIX相同但油價更低，因此3/3的大盤比3/10便宜？！  '
#              '實際上3/3還在3.4萬，比3/10貴了1500點。  '
#              '事實證明看石油多少錢、人們為了未來多單的保費多貴，來判斷進場時機，本身就是一種 '
#              '極度模糊的韻律感整理，這種不能說錯，股票市場本來就是在戰爭迷霧中找出路，但是說 '
#              '持續買進這種科學方法錯然後模糊直覺對，那就是以拿破崙的天才來否定普魯士參謀制度 。  '
#              '科學化的投資方式，適合不是天才的人，沒有頭緒該怎麼做就0050持續買，高也買低也買 '
#              '，不是在那邊空手等油價噴VIX飆，看指標的話，那12/01後應該都空手現在，那是錯過多 少行情。      -- '
#              '有長期研究顯示VIX進出SP500 報酬率大概落在5-7% 買進持有11% 主要是20年的時間錯過20天報酬就歸零 '
#              '要猜對機率只有0.3% 即使加入許多指標仍然很難全對 如果完美避開最好與最差的各20天 '
#              '20年報酬率大概12%，比11%高1%年化 但這要判斷100%正確才行 只有上帝能做到 VIX在一些報復性反彈時會失準 '
#              '（市場還在恐慌但資金已經入場）',
#   'time': 'Wed Mar 11 12:49:51 2026',
#   'title': 'Re: [標的] 0050持續買進',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1773204595.A.AA2.html'},
#  {'comments': [],
#   'content': '結果來看，目前只加碼到五張0050和日常的定期定額而已（107張變成112張），本來以為這波至少到28000，打算從35000一路往下每天一張（準備了50張的彈藥，自備現金沒貸款），不知道為什麼明明還全是壞消息，股價卻上去了，接下來看能不能到33000以下繼續每天一張。   '
#              '定期定額 ， 0050 ， 自強不息  台股，我來撐！！！    ----- Sent from JPTT on my '
#              'Google Pixel 7a.  -- 不知道欸，反正我天天花5500買，管他的，沒加碼到就算了 '
#              '目前還在債券裡面，本來是這波要轉換成0050，大概還可以換50張 啊我就抱不住正二啊？？？？ '
#              '大神，佩服你，我發現0050和VT是我唯二抱的住的，0056我真沒辦法 厲害，我沒辦法一次補這麼多貨，總是錯過機會',
#   'time': 'Wed Mar 11 10:56:25 2026',
#   'title': 'Re: [標的] 0050持續買進',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1773197787.A.277.html'},
#  {'comments': [],
#   'content': '剛剛也先補了500零股 湊滿整數 https://i.imgur.com/3D7lhde.jpg  '
#              '不過照圖中推文覺得還會繼續跌的說法 好像覺得現在入場太早了? 但能推測會繼續跌的話 為什麼這些人不壓身家空期貨? '
#              '跌到2萬或者一萬五千點隨便都擠百甚至幾千萬入帳吧  其實我自己也思考過現在獲利300w賣掉 跌回去再買不是賺很多? '
#              '但那樣子好像就失去存股的意思了 能猜漲跌我碰期貨就好 一直很懊悔剛出社會沒買到當年2x元 (分割之前的0050 '
#              '希望能夠像這樣繼續堅持存股下去  (雖然真的跌到萬五的話 帳面上會變成負的 應該還是心會很痛QQ)  --',
#   'time': 'Mon Mar  9 12:34:52 2026',
#   'title': 'Re: [標的] 0050持續買進',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1773030895.A.D8B.html'},
#  {'comments': [],
#   'content': '0050持續買，無腦買，當現金買，只要台股的資金成本繼續長期便宜，光是買0050也是太 保守的做法。  '
#              'https://i.mopix.cc/ZxgOCR.jpg  '
#              '就算買滿也在白色的低效率區，台股上市櫃公司長期真金白銀賺入14.15%的年均報酬，政 '
#              '府又努力壓物價壓利率，整個經濟機器有利股東，只要不急著用錢，買一買放一放就賺錢 了。  '
#              '有eps，就能透過DDM（股價折現）反映的內在價值，推算出預期報酬。  '
#              'https://i.mopix.cc/pz7lmI.jpg  因為我們求預期報酬，移動一下r。  '
#              'https://i.mopix.cc/kSSA19.jpg  '
#              '今年上市櫃EPS預期成長15%，你買在35500，或是28500，差別只是賺多少。  買在35500 預期報酬19%：  '
#              '1240*1.15/35500+0.15=0.19  買在28500 預期報酬20%：  '
#              '1240*1.15/28500+0.15=0.2  https://i.mopix.cc/gdwaQf.jpg  '
#              '況且AI基礎建設才第一年，一場區域戰爭阻止不了趨勢，台積電再不濟也頂多放慢擴廠腳 步，台股雞本麵好吃。  '
#              '真的要顧慮進出的，只有超過一倍槓的投資人。或是個股有跌了回不去的可能性。  '
#              '才差1%年化，除非你槓桿才有差別，原型長期買進去沒差很多，有抄到底小確幸，沒抄到 底放久還是賺。  '
#              'https://i.mopix.cc/hdDlmI.jpg  -- 歡迎長期放空 我是買正二調整槓桿啦 '
#              '那個綠色區才是資金成本的甜蜜點 1%指長期年化 你那邊卡在25/04卡死了 建議重開機一下 避險產品大跌切正二基操 '
#              '風險都反映完了不抄底在哈囉？ 長期不會差很多，清流君也有拉歷史來看過，神跟平常人也是差1%，就像我這邊推算的一 樣。 '
#              '這篇給你信心買入持有，原型買在哪都差不多，長期年化差1%     https://i.mopix.cc/Rz5AOA.jpg '
#              '我目前是150%上下 等28500調整到200%（正二） 28500以下才適合正二的意思 '
#              '31000只適合75%正二25%現金（150%） 這邊要抄底不適合用槓桿抄 用0050抄比較穩 '
#              '都教關稅股災賣713抄正二了，喊盤喊到去年10月，你都不做我有什麼辦法？ 我早就在去年四月200%以上了== 錢錢早乾了 '
#              '戶頭剩2000元 30000開始降槓桿，剛好大跌前降到150%左右 我這篇是說原型不用怕 隨便買 黃金沒有辦法回推內在價值 '
#              '有點靠信仰',
#   'time': 'Mon Mar  9 11:42:32 2026',
#   'title': 'Re: [標的] 0050持續買進',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1773027755.A.073.html'},
#  {'comments': [],
#   'content': '看著完美風暴形成，我現在超興奮的，正好讓我把美債蛋雕，從34000開始就每天下跌買一張，大概還能買50張，目前應該是我經歷過的第三個多空循環    '
#              '第四年，定期定額，持續買，買買買買買買！！！！http://i.imgur.com/M1DL0IB.jpg   '
#              '目前從高點下來已經少140萬了！  台股，我來撐，這就是愛呆灣  '
#              'http://i.imgur.com/X4J1TVa.jpg    ----- Sent from JPTT on my '
#              'Google Pixel 7a.  -- 我就是要放一輩子，大概20年後每年4%慢慢提領（含2%股息） '
#              '大戶欸，一出手就是我80%資金 我最初一年半定期定額後是-27.9%，有沒有感覺好一點？ 有可能，我不知道，管他的，老子有錢 '
#              '我本來就每天都在買啊，大概一個月合計買16萬，已經買四年了 '
#              '這波資金沒了還有定期定額，再加上都是用不到的閒錢，沒任何負債，空頭三四年也不怕啊，再加上我要放一輩子，之後用4%提領就好 '
#              '一出手就是我的20%，敬禮！！ 腰斬大概就回到我的成本價，好像還好 '
#              '怕誤會先說一下，我沒在歐印的喔，就是慢慢買，沒買到就算了，反正我天天都在定期定額 '
#              '其實，我投入成本大概800，獲利含息之前是600，現在大概450，還有其實我也沒擔心過虧損啊？定期定額本來就不是賺大錢的，我每個月含息也才投16萬，四年本來就只能這樣而已，我又不是股神，只是一直買而已 '
#              '確實我前幾天爬山時候被岩壁撞到頭，有破皮',
#   'time': 'Mon Mar  9 10:29:52 2026',
#   'title': '[標的] 0050持續買進',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1773023394.A.047.html'},
#  {'comments': [],
#   'content': '最近大盤不穩，預估週一大盤應該跌破月線  大家持股有0050或0056的會停利賣出嗎？  '
#              '眼看著獲利越來越少，成本也沒有到很低，  怕這次中東戰爭會跌到成本以下，小妹只是小資族一個，還是跌到成本以下加碼就對了？  '
#              '或者目前先出清入袋為安，留銀彈等落底再買？  不知道有這兩檔股票的大家怎麼操作？ ----- Sent from JPTT on '
#              'my iPhone  --',
#   'time': 'Sun Mar  8 11:23:34 2026',
#   'title': '[請益] 0050跟0056有在停利的嗎？',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1772940216.A.B05.html'},
#  {'comments': [],
#   'content': '這位同學，請看我前幾天的文章。 現在油價來到2022年的高位， 是讓你賣股票，不是買股票， 2022年幾乎一整年的熊市。 '
#              '原因為什麼，請問gemini。 學會抓轉哲，很重要。 禮拜一出掉大部分股票， 並在今天加碼石油正2。 '
#              'https://i.imgur.com/mjZpiKK.jpeg '
#              'https://i.imgur.com/I9ryKIH.jpeg   -- 等待國際局勢穩定，大長紅k棒 今天有開始慢慢撿鑽石了',
#   'time': 'Fri Mar  6 23:21:04 2026',
#   'title': 'Re: [請益] 0050轉正二',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1772810466.A.60E.html'},
#  {'comments': [],
#   'content': '原文標題：  快訊／規模1.3兆0050換股！增刪5檔\u3000華邦電入列、踢萬海  原文連結：  '
#              'https://reurl.cc/qpDbED  發布時間：  2026-03-06 17:20  記者署名：  巫彩蓮  '
#              '原文內容：  富時羅素公布下列有關元大臺灣50（0050）追蹤臺灣50指數成分股調整，分別增、刪五檔  '
#              '個股，成分股納入金像電(2368)、鴻勁(7769)、京元電子(2449)、欣興(3037)、華邦電  '
#              '(2344)；成分股刪除貿聯-KY(3665)、聯詠(3034)、統一超(2912)、瑞昱(2379)、萬海  (2615)。  '
#              '0050從2003年成立以來至今（2026）年1月底，資產規模突破兆元，近期資產規模來到1兆  '
#              '3316.8億元，此次0050將自今年3月20日交易結束後生效，亦即自今年年3月23起生效。   心得/評論：  0050 '
#              '也很會調整啊 馬上刪除不看好的股票 投進好的股票 難怪大家定期定額買0050  而不丟到定存去 每個人有自己的想法啦 '
#              '我也不會去鼓吹別人要投0050。  重點就是 投資理財有賺有賠。  --',
#   'time': 'Fri Mar  6 17:40:40 2026',
#   'title': '[新聞] 快訊／規模1.3兆0050換股！增刪5檔\u3000華',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1772790042.A.7A1.html'},
#  {'comments': [],
#   'content': '一樣，看得懂算你有緣，看不懂可以按左離開。  一、名目槓桿與實質槓桿的釐清  先從最簡單的問題開始： '
#              '在一個隨機的賭場賭局，令你的資金=1000，勝率=0.5，限定下注次數=2， '
#              '賭贏可獲得下注金額的錢，賭輸則失去。若資金<0則終止賽局。 '
#              '你可以借資金比1:1的錢來賭，故首次投注資金=1000+1000=2000(200%)， 那麼可能的結果與機率為何？  '
#              '贏兩次       1/4    9000 (第一次賭2000，第二次賭6000，最終9000) 第一次輸     2/4   '
#              '-1000 (-100%) 反勝為敗     1/4   -3000 (第一次賭贏，第二次賭輸要賠賭場3000)  '
#              '那麼，你要賭25%機率賺9倍，代價是75%會破產虧-1000~-3000嗎？  --  我們再從期望值的角度出發：  '
#              '期望金額=(0.25*9000)+(0.25*-3000)+(0.50*-1000)=1000  '
#              '那你就會很明白，只單純看大賺情境來論為何不做的人。 '
#              '或者拿大賺歷史來辯駁的人，本身都只是把情境縮在(0.25*9000)的"事實" '
#              '但在這個賭局事件中，其他三項不會存在嗎？存在，只是還沒發生成為事實。  '
#              '如果你真的在乎你的錢的話，那麼你就應該客觀地看所有情境下的損益； '
#              '只討論暴賺的歷史情境，那本身就是一件很低級的事情，完全沒有討論價值。 你只是在浪費你自己的時間而已。  '
#              '那麼，為何期望金額剛好會等同於你初次下注金額的1000？ 這會回答一個很常見的現象：你是不是特地借錢開槓桿做沒有意義的事情？  '
#              '在本次設計的賭局模型中，單次期望值(E)=0.5*(下注金額)-0.5*(下注金額)=0 '
#              '你特別開n倍的槓桿，結果也只是n*0=0。本質上沒有任何的意義。  '
#              '甚至可以說，如果在期望值未知或等於0的狀態下，你把倍數放大，反而會更糟。  --  '
#              '我們再從另一個情境來看，只增加一個參數：投注比例。  '
#              '同樣規則的賭局，資金=1000，投注比例=0.1，代表你單次只會投10%的錢。 '
#              '你一樣跟賭場借同樣下注金額的錢，100+100=200。  那麼你在做怎樣的事情？ '
#              '這就很重要的，雖然看起來你還是做單筆1:1的槓桿，也就是名目槓桿倍率200%。 '
#              '但你限定了投注比例，所以實質槓桿比例=200/1000=20%。 你實際上是縮小了投注比例，那這在同樣的賽局會有怎樣結果？  '
#              '贏兩次    25%  1400 (+40%) 一勝一負  50%  1000 輸兩次    25%   600 (-40%)  '
#              '最大的差異就是由於倍率減小，你就不會破產了。  「你規則不對阿，應該是賭贏的錢全部繼續1:1的借200%名義槓桿才對啊？」  '
#              'ok，就退百步來看會發生哪種結果。  --  贏兩次     1000+200+600=1800 先贏後輸   '
#              '1000+200-600=600 先輸後贏   1000-200+200=1000 輸兩次     '
#              '1000-200-200=600  乍看似乎是更好，似乎是找到加減碼的聖杯？ '
#              '但如果你算期望值：每個機率=0.25，則E=450+150+250+150=1000  '
#              '這只是在證明一件事情，如果期望值為0，那你怎麼加減碼，改變倍率； '
#              '或者單純不改變倍率，它都不會真的如你所願地把期望值"從0變1"， '
#              '這個在做的事情，單純只是把倍率提高，所以變異數和標準差也會變大。  你賭的是連贏的資產暴增，但同樣也要接受沒有連贏的"耗損"。 '
#              '這是數學上的必然，你無法避免。  那麼你看到這邊，還會選擇要動態加減碼、或者加大倍率來增加曝險金額嗎？ '
#              '如果你本質上都是做同樣的事情，為何不更簡化來做更容易計算與維護的方法呢？  說穿了這就是00631L在做的事情。  --  '
#              '這世界就是這樣，你可能找很久的東西結果概念就在人家的公開說明書而已。  二、擇時的幻覺  '
#              '寫這些東西的人，以及基於建立規則來假定的模型，為何這些人不選擇擇時呢？  '
#              '我認為，這群人通常會有一個特性，那就是會承認：我不知道。 例如：我承認並接受價格可能是隨機波動的，我不知道未來的價格是怎樣。  '
#              '而承認"我不知道"，你才有基礎來討論：假設價格未知，那我要怎麼達到等比例 '
#              '的投注，以及等比例地控制虧損金額？那你才會知道怎麼樣算出名目槓桿200%， '
#              '但你實質槓桿要幾%，才不會讓自己破產或無法接受，從而繼續執行。  '
#              '當然有的人可以反駁「那只是你不知道而已，你不知道就等於不存在？白癡」  '
#              '但重點在於，當規則已經可以把"不知道"變成"可控制的結果"， 那麼就算只是我不知道，也不會有太大的影響。而且甚至沒有意義。  '
#              '例如，如果是以台指期為操作商品的00631L，那麼它本質上的獲利因子為何？  --  '
#              '其實說穿了，00631L的獲利核心跟0050差不多，也就是賺取市場，也就是Beta的收益。  '
#              '然而這邊存在一個問題：你可以用過去的歷史平均Beta值，來預期未來的Beta值嗎？  '
#              '答案是不行，而這可以說明為何擇時反而不會有好結果。 你部位是否每天在市場內，其實存在著機會成本，例如最近的例子。 '
#              '假設你嫌年後周一到周三的選擇權契約點數太貴，而不做那麼你就會錯過這次暴漲。 那麼就你的資金曲線和理論的策略曲線，就會存在誤差。  '
#              '以及很常見講到爛的，經常有人把時間取樣為2021年大跌前買00631L，來看報酬率 '
#              '報酬率當然會有變化，因為這回歸到一個基礎：歷史報酬率、歷史Beta會隨著 '
#              '你樣本的時間長度而改變，所以本質上再取平均也是不穩定的統計量。  那麼剩下的重點，就不在於：我相信Beta是正的，所以我要執行。 '
#              '而是承認我不知道未來的beta是怎樣，但我可以在變化時都可以保持一定曝險。 剩下骰出來的beta是多少，就看隨機骰出的結果。  '
#              '那麼擇時、抓轉折，如果你企圖賺的是Beta，那麼正常情況下，你不應該放棄機會成本 '
#              '來造成行情來了你卻沒有部位的誤差。這是倒果為因的愚蠢。  --  '
#              '當然我並不是說你必須永遠都在市場上。還記得上一頁我講的是"正常"嗎？ '
#              '實際上的確會存在很不正常的環境，例如本周三的周選擇權就是一個例子， 現實的環境是存在一些"摩擦"的成本而導致不正常的結果，  '
#              '例如假設在一個高價格波動環境，可以預期高的隱含波動率，但造市商也不想承擔風險。 '
#              '那他就會降低或乾脆不鋪單，所以委買委賣更差會導致更差的價格與成交效率， '
#              '在這個情況下可以把任何選擇權策略，包括垂直價差都變成無利可圖的環境。  '
#              '那當然在這種環境下不做是很合理的選擇，至於你如果又錯過了後來的行情。 '
#              '就會回歸到最基本的，那是你已經看到答案，如果答案未知而且沒有發生， 你願不願承受比預期高的高額虧損，答案就顯而易見。   '
#              '三、結果未知的隨機賭局  我想可能會有人想反駁「既然說未知你怎麼會知道勝率和賺賠比多少， 你講的模型根本沒有，北七」  '
#              '那麼，就來做一個實驗來模擬這種期望值會因為價格隨機而變動的狀況。  --  '
#              '令資金=10000，單次賺賠損益取決於骰出數列的一數=[-1,0,1,2]， '
#              '也就是模擬出一個很常見的固定賺賠比制的交易策略，只要打到-1停損，+2停利。 但實際上存在0,1的結算價的損益。  '
#              '投注比例=0.5，投注次數=2次，名目槓桿率=1:1=2倍的結果。 '
#              '由於第一次和第二次可能會各有4種值的結果，用excel算數列可以得出：               第      二      '
#              '次 第一次   -1 (全賠)   0      1 (贏 1x)    2 (贏 2x) -1       2,500     '
#              '5,000     7,500        10,000 0        5,000    10,000    '
#              '15,000        20,000 1        7,500    15,000    22,500        '
#              '30,000 2       10,000    20,000    30,000        40,000  '
#              '由於平均期望值=0.5，所以這個投注策略應該可以賺錢。 但我們講過的，由於投注比例高，你還是會有： (1)最左上方的大賠虧損 '
#              '(2)左上方的"震盪"耗損  所以這代表什麼？這代表進十步而言，就算期望值為正，數學上的耗損必然會存在。 '
#              '只是你有沒碰到而已，如果時間一長必然會成為常態。 --  '
#              '那你覺得極端狀態會-75%不能接受，而認為某作者認為的50/50重分配法不好。 '
#              '你沒有辦法接受這種耗損，那答案就很簡單：你把比例調低就好了。 '
#              '只要調到一個你看右下方很爽左上方可以接受的結果，基本上就可以解決很多問到爛 的問題。至於你要問有沒有更好的辦法？   '
#              '當然有，你想想看平均期望值怎麼算的。怎樣可以把期望值拉高？ 但最終來說你還是會得到跟指數型ETF長期持有的結果差不多。  '
#              '所以講那麼多，說到底就只是你想要用多少的投注比例來換隨機的結果而已。 '
#              '了解你的實質槓桿才是主要控制方法，ETF標榜的名目槓桿200%只是倍率。 '
#              '而你可以靠下多少來控制倍率的損益，並接受數學上耗損是必然的結果。 那就不會有太多的疑慮。  --',
#   'time': 'Fri Mar  6 17:21:31 2026',
#   'title': 'Re: [新聞] 台股大跌0050打折！清流君曬0050歷史回',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1772788894.A.2FE.html'},
#  {'comments': [],
#   'content': '標題：  臺灣證券交易所與富時國際有限公司 合編之臺灣指數系列及臺灣高股息指數成分股定期審核結果  來源：TIP 臺灣指數公司  '
#              '網址：https://taiwanindex.com.tw/news/405  內文：   '
#              '富時羅素公布下列有關臺灣50指數、臺灣中型100指數、 臺灣資訊科技指數、臺灣發達指數及臺灣高股息指數審核結果。    '
#              '如有指數成分股在下次定期審核前之期間被刪除，將以本次候補名單遞補， 候補名單自即日起生效。  '
#              '自指數審核生效日起之連續五個交易日為指數定期審核過渡期， 此期間每檔股票之權重採用過渡期間權重， 過渡期間生效日為  '
#              '富時羅素依據2026年2月23日資料審核結果如下，彙總說明如附表：          (三)候補名單： '
#              '華城(1519)、創意(3443)、南電(8046)、藥華藥(6446)、力積電(6770)。   二、臺灣中型100指數  '
#              '(一)成分股納入： 貿聯-KY(3665)、高力(8996)、景碩(3189)、旺宏(2337)、聯詠(3034)、 '
#              '統一超(2912)、瑞昱(2379)、新代(7750)、聯邦銀(2838)、萬海(2615)。  (二)成分股刪除： '
#              '玉晶光(3406)、金像電(2368)、材料*-KY(4763) 、京元電子(2449)、 '
#              '三陽工業(2206)、台肥(1722)、中保科(9917)、欣興(3037)、 華邦電(2344)、裕融(9941)。  '
#              '(三)候補名單： 群益證(6005)、長興(1717)、台勝科(3532)、國票金(2889)、 '
#              '中砂(1560)、帆宣(6196)、潤弘(2597)、矽格(6257)、華新科(2492)、洋基工程(6691)。         '
#              '四、臺灣發達指數  (一)成分股納入：高力(8996)、新代(7750)。  '
#              '(二)成分股刪除：材料*-KY(4763)、三陽工業(2206)、台肥(1722)、中保科(9917)。      '
#              '(一)成分股納入：無。    --',
#   'time': 'Fri Mar  6 17:12:54 2026',
#   'title': '[情報] 0050 006208 0056 成分股定期審核結果',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1772788377.A.780.html'},
#  {'comments': [],
#   'content': '路徑依賴 是跟正2產品的特性相關 或是說和槓桿類產品相關  舉個例子來說 路徑一： 假設台股三萬點  每天暴漲暴跌 用漲1300 '
#              '跌1000點的方式走到33000  共經20個交易日 報酬約為 17.93%  被扣血了2.07%     '
#              '路徑二：每天漲150點 20個交易日 報酬約為20.95%  多了0.95%   如果採用微大小台期 2倍槓桿  那麼不管路徑1 '
#              '2都是20%   如果這個路徑1 路徑2連續發生  如果路徑1 連續發生三個月 也就會產生  有感的波動率耗損    '
#              '總報酬58.5% 如果路徑2 連續發生三個月  會產生巨額的超額報酬            總報酬   68.8% '
#              '也就是網友說的暴擊  至於長持期貨 就60%  路徑依賴指的是這個  因為每日在平衡的特性 造成這個產品 會因為不同的路徑 '
#              '即便是終點相同也會有不同的報酬 可能是超額報酬 也可能是耗損  對比真實世界  2024.6  台期       22983  '
#              '2025.7 23589   大約+2% 2024.6  00631L     250.8  2025.7  245.2   '
#              '大約-1%  不同的路徑會影響正2的報酬 是產品的特性  成本或是利率 或最佳槓桿率 是操作的調整與搭配 是投資策略的問題   '
#              '路徑依賴是因為每日再平衡產生的槓桿類產品的特性  和最佳槓桿率比較沒有直接的關係  補充一下  如果是反過來 一樣下跌三千點  '
#              '路徑一 20個交易日 下跌三千點 那麼就會產生 21.75%的虧損 '
#              '路徑二                                 產生 19.05%的虧損 '
#              '期貨                                         20%的虧損  路徑一一樣超額虧損 '
#              '路徑二一樣績效會比原型好  其實對正二最好的路徑就是連續 連續漲 連續跌  不要漲漲跌跌  '
#              '所以認為不可長持的觀點可能就會有這一個：  股市是隨機的 萬一正2走漲漲跌跌的路線 會產生可能持有原型正績效 '
#              '持有正2負績效    不過正2的優點也很多 對比期貨 持有正2簡單很多  我自己是有正2也有用期貨 大約三年了 '
#              '正2是對於想開槓桿的投資者 很方便的工具  對於長期想槓桿投資的人來說 正2你比較沒有手癢的機會  期貨晚上也能交易 '
#              '有時候看著AVAV 就多做了不該做的動作 大概是這樣    引述《onekoni (一貓人我的超人)》之銘言：  --  '
#              '槓桿etf說的路徑依賴說的是ETF再平衡造成的結果或說是現象  蜈蚣王您要表達的是最適槓桿率  以及大環境的背景的路徑依賴  '
#              '但是etf的路徑依賴就是單純波動造成的現象  可能在這邊的表達上有差異   您的想法就是依據不同產品的特性 產生自己的策略來持有 '
#              '這個就是一種變通的方式 其實都可以試看看   我自己用期貨部分替代 約3年 正2確實簡單多了 也可以考慮用期貨 長持是也可以 '
#              '另外可以用不同市場BETA做再平衡  長持期貨 其實沒有想像中容易 至少對我來說是 '
#              '應該說正2在特定路徑會贏2倍期貨            也會在特定路徑會輸2倍期貨  可以考慮兩個互相搭配  理論數值上面有 '
#              '連續下跌會跌得少些 對比真實時間數據 我找了幾個連續下跌的時間段 周線 2022.6.10 16471  2022.7.1 '
#              '14175   跌幅13.94%  2倍 27.88% 正2        118.75         '
#              '92.35                 跌幅22.23  只要是有明顯的連續下跌應該都會有類似的狀況  2022.9.2  '
#              '14597       2022.9.30 13395      -16.46% 00631L    '
#              '99.4                    83.2       -16.3%  實際上只要是連續的某個動作 '
#              '正2都會獲得超額的報酬 或是減少虧損  這也很容易理解 正二因為每日重新計算 會造成"波動率的耗損" 等於曝險金額 '
#              '每日均在改變   台期因為購入後  是以點數購入的 並不會變來變去  所以漲一百點跌一百點 不會有損益  正2追蹤期貨  '
#              '今天漲一百點結算 會是一個新的價 明天跌一百點 那麼用的價格是昨天漲一百點的價格 自然會有變動',
#   'time': 'Fri Mar  6 07:22:02 2026',
#   'title': 'Re: [新聞] 台股大跌0050打折！清流君曬0050歷史回',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1772752924.A.B6E.html'},
#  {'comments': [],
#   'content': '我大推正2，但前提是，要會抓轉哲。 https://i.imgur.com/QRq9IdW.jpeg '
#              '週一早上開盤馬上出掉，避開連兩天下跌。  什麼時間點該進，什麼時間點該減碼，該出場， '
#              '要看技術指標，短線RSI指數，美股科技股走勢， 國際局勢環境，國際原油價格，vix恐慌指數， 不能賭博。 '
#              '過年前連漲三天，開工後又連漲五天， 而美股已經在下殺了，油價已經在飆漲了， 當然要先出場。  '
#              '擇時進場很重要，不是無腦買0050就會賺錢， 從今年開始買納斯達克，還賠錢。 買個股都要知道買低基期，買便宜的， '
#              'ETF也是。    -- 我正2這筆賺了15%，正在找更低的點買回來。跟抱著不賣的比，穩贏。 '
#              '明天跌到更低，我全部買回來，更便宜，不就穩贏了? 連漲10天的機率高，還是跟隨美股的機率高，漲跌是1/2嗎 '
#              '從過去的RSI指數來看，過高反彈的機率非常大，真以為在賭博嗎 '
#              '我是說跟抱著不賣的比，因為已經多15%的現金，除非明天彈回賣點209元囉。 '
#              '最好的賣點其實是上周五214元，我還覺得我賣得不夠好。 你覺得台股連漲10天的機率高嗎? 可以完全不甩美股連跌兩天? '
#              '台股跟美股就像主人與狗，乖離大，必定修正。 我是靠技術分析，過去經驗判斷，不是靠感覺。 只要願意認錯買回，哪裡輸? '
#              '七成以上準確，一定贏。 我賣了四張，接下來就要找時間把四張買回來。 七八成以上會有更低的價格，長期下來，怎麼輸? '
#              '比特幣沒有美股/油價 仙人指路，不賭博 倒是昨天撿了不少便宜黃金白銀，參考參考 賣出不能買回? '
#              '正乖離拉回來，就可以進場了，外資喊台積電到2330以上。 最近拉回就是找買點。',
#   'time': 'Fri Mar  6 00:40:33 2026',
#   'title': 'Re: [新聞] 台股大跌0050打折！清流君曬0050歷史回',
#   'url': 'https://www.ptt.cc/bbs/Stock/M.1772728835.A.134.html'}]
